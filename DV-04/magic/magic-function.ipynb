# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
plt.plot(5,5, 'x')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.xlabel('X')
# Out:
# Text(0.5, 0, 'X')
