# %%
import pandas as pd

df0 = pd.read_csv('canada-mig-dataset.csv')
df1 = df0.loc[ df0['OdName'].isin(["China", "India", "Haiti"]) ]
df2 = df1.set_index('OdName')
df3 = df2.iloc[:, 8:42]
df4 = df3.transpose()
df4.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
df4["Haiti"].plot(kind='line')
plt.title("Immigration from Haiti")
plt.ylabel("Number of Immigrant")
plt.xlabel("Years")
# Out:
# Text(0.5, 0, 'Years')

# %%
df3_ = df2.loc[["China", "India", "Haiti"], ["1980","1981","1982"] ].plot(kind='line')
